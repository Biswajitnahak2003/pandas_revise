# %%
import pandas as pd

# %%
## series
height = pd.Series(data = [20,25,34,27,22,25,35,23], dtype="f16")
height
# Out:
# 0    20.0
# 1    25.0
# 2    34.0
# 3    27.0
# 4    22.0
# 5    25.0
# 6    35.0
# 7    23.0
# dtype: float128

# %%
## dataframe
data = {
    "name" : ["biswajit", "om", "akash"],
    "age": [22, 23, 45],
    "city": ["bbsr", "rourkela", "delhi"]
}
df = pd.DataFrame(data)

# %%
## reading csv
dataset = pd.read_csv("dataset/financial_audit.csv")

## read excel
# ex = pd.read_excel("filepath")

## read json
# json = pd.read_json("filepath")

# %%
# first 5 rows
dataset.head()
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
#
#   reconciliation_status
# 0               CLEARED
# 1               CLEARED
# 2               CLEARED
# 3               CLEARED
# 4               CLEARED

# %%
## first 10 rows
dataset.head(10)
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status
# 0               CLEARED
# 1               CLEARED
# 2               CLEARED
# 3               CLEARED
# 4               CLEARED
# 5               CLEARED
# 6               CLEARED
# 7              REJECTED
# 8               CLEARED
# ...

# %%
## last rows
dataset.tail()
# Out:
#       tx_id                                        audit_trail  \
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status
# 5               CLEARED
# 6               CLEARED
# 7              REJECTED
# 8               CLEARED
# 9               CLEARED

# %%
## whole dataset
dataset
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status
# 0               CLEARED
# 1               CLEARED
# 2               CLEARED
# 3               CLEARED
# 4               CLEARED
# 5               CLEARED
# 6               CLEARED
# 7              REJECTED
# 8               CLEARED
# ...

# %%
## shape
dataset.shape
# Out:
# (10, 3)

# %%
## columns
dataset.columns
# Out:
# Index(['tx_id', 'audit_trail', 'reconciliation_status'], dtype='str')

# %%
## information
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tx_id                  10 non-null     str
#  1   audit_trail            10 non-null     str
#  2   reconciliation_status  10 non-null     str
# dtypes: str(3)
# memory usage: 372.0 bytes

# %%
## statistics
dataset.describe()
# Out:
#            tx_id                                        audit_trail  \
# count         10                                                 10
# unique        10                                                 10
# top     TXN_5000  Client: Alice Smith | Region: London | Deposit...
# freq           1                                                  1
#
#        reconciliation_status
# count                     10
# unique                     2
# top                  CLEARED
# freq                       9

# %%
## datatypes
dataset.dtypes
# Out:
# tx_id                    str
# audit_trail              str
# reconciliation_status    str
# dtype: object

# %%
## creating new column
dataset["country"] = ["england ", "FRance", "Japa n  ", "", " ", "USA", "AustraliA", "Usa", "India", "USA"]
dataset
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status    country
# 0               CLEARED   england
# 1               CLEARED     FRance
# 2               CLEARED   Japa n
# 3               CLEARED
# 4               CLEARED
# 5               CLEARED        USA
# 6               CLEARED  AustraliA
# ...

# %%
## drops from a copy 
dataset.drop(columns = ["country"])
dataset
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status    country
# 0               CLEARED   england
# 1               CLEARED     FRance
# 2               CLEARED   Japa n
# 3               CLEARED
# 4               CLEARED
# 5               CLEARED        USA
# 6               CLEARED  AustraliA
# ...

# %%
## permanent drop
dataset.drop(columns=["country"], inplace=True)
dataset
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status
# 0               CLEARED
# 1               CLEARED
# 2               CLEARED
# 3               CLEARED
# 4               CLEARED
# 5               CLEARED
# 6               CLEARED
# 7              REJECTED
# 8               CLEARED
# ...

# %%
## creating new column
dataset["country"] = ["england ", "FRance", "Japa n  ", "", " ", "USA", "AustraliA", "Usa", "India", "USA"]
dataset
# Out:
#       tx_id                                        audit_trail  \
# 0  TXN_5000  Client: Alice Smith | Region: London | Deposit...
# 1  TXN_5015      client=Bob Jones; region = Paris; deposit=300
# 2  TXN_5030  Client: Charlie Brown; Region: TOKYO; Amount: ...
# 3  TXN_5045  Client: Diana Prince; Region: Gotham; Deposit:...
# 4  TXN_5060  Client: Evan Wright | Region: Berlin | Deposit...
# 5  TXN_5075  Client: Fiona Gallagher; Region: Chicago; Depo...
# 6  TXN_5090  Client: George Clark | Region: sydney | Deposi...
# 7  TXN_5105  Client: Hannah Abbott | Region: Boston | Depos...
# 8  TXN_5120      client=Ian Malcolm; region = ; deposit=500.00
# 9  TXN_5135  Client: Julia Roberts; Region: Hollywood; Depo...
#
#   reconciliation_status    country
# 0               CLEARED   england
# 1               CLEARED     FRance
# 2               CLEARED   Japa n
# 3               CLEARED
# 4               CLEARED
# 5               CLEARED        USA
# 6               CLEARED  AustraliA
# ...

# %%
dataset.to_csv("dataset/modified_audit.csv", index=False)
